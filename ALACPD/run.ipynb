# %%
# !cd datasets/std && python create.py
# Out:
# [84]

# %%
# !bash run.sbatch
# Out:
# + model_name=AE_skipLSTM_AR
# + seed=0
# + windows=6
# + train_percent=0.1
# + dataset=std
# + e_init=10
# + e_train=5
# + e_reinit=100
# + n_cpd=10
# + unit=20
# + horizon=4
# + highway=6
# + skip_sizes='3 5 7'
# + python3 -W ignore ./code/main.py --dataset_name std --seed 0 --windows 6 --train_percent 0.1 --model_name AE_skipLSTM_AR --unit 20 --horizon 4 --highway 6 --skip_sizes 3 5 7 --e_init 10 --e_train 5 --e_reinit 100 --n_cpd 10
# Namespace(dataset_name='std', e_init=10, e_reinit=100, e_train=5, highway=6, horizon=4, model_name='AE_skipLSTM_AR', n_cpd=10, seed=0, skip_sizes=[3, 5, 7], train_percent=0.1, unit=20, windows=6)
# ...

# %%
# !python exact.py
# Out:
# 7 0.21658471928380585 13 0.18159319941181562
# 7.246425
# Figure(640x480)
# 84

# %% [markdown]
# ![alacpd](./results_AE_skipLSTM_AR/std/seed=0/log/1.png)
# ![exact](./exact_fig/1.png)

# %%
# !cd datasets/std && python create.py
# Out:
# [135]

# %%
# !bash run.sbatch
# Out:
# + model_name=AE_skipLSTM_AR
# + seed=0
# + windows=6
# + train_percent=0.1
# + dataset=std
# + e_init=10
# + e_train=5
# + e_reinit=100
# + n_cpd=10
# + unit=20
# + horizon=4
# + highway=6
# + skip_sizes='3 5 7'
# + python3 -W ignore ./code/main.py --dataset_name std --seed 0 --windows 6 --train_percent 0.1 --model_name AE_skipLSTM_AR --unit 20 --horizon 4 --highway 6 --skip_sizes 3 5 7 --e_init 10 --e_train 5 --e_reinit 100 --n_cpd 10
# Namespace(dataset_name='std', e_init=10, e_reinit=100, e_train=5, highway=6, horizon=4, model_name='AE_skipLSTM_AR', n_cpd=10, seed=0, skip_sizes=[3, 5, 7], train_percent=0.1, unit=20, windows=6)
# ...

# %%
# !python exact.py
# Out:
# 16 0.9410324671210936 25 0.14846166562699914
# 16.459653
# Figure(640x480)
# 135

# %% [markdown]
# ![alacpd](./results_AE_skipLSTM_AR/std/seed=0/log/2.png)
# ![exact](./exact_fig/2.png)

# %%
# !cd datasets/std && python create.py
# Out:
# [148]

# %%
# !bash run.sbatch
# Out:
# + model_name=AE_skipLSTM_AR
# + seed=0
# + windows=6
# + train_percent=0.1
# + dataset=std
# + e_init=10
# + e_train=5
# + e_reinit=100
# + n_cpd=10
# + unit=20
# + horizon=4
# + highway=6
# + skip_sizes='3 5 7'
# + python3 -W ignore ./code/main.py --dataset_name std --seed 0 --windows 6 --train_percent 0.1 --model_name AE_skipLSTM_AR --unit 20 --horizon 4 --highway 6 --skip_sizes 3 5 7 --e_init 10 --e_train 5 --e_reinit 100 --n_cpd 10
# Namespace(dataset_name='std', e_init=10, e_reinit=100, e_train=5, highway=6, horizon=4, model_name='AE_skipLSTM_AR', n_cpd=10, seed=0, skip_sizes=[3, 5, 7], train_percent=0.1, unit=20, windows=6)
# ...

# %%
# !python exact.py
# Out:
# -18 0.502204206503372 -9 0.2224660045104505
# -17.397747
# Figure(640x480)
# 148

# %% [markdown]
# ![alacpd](./results_AE_skipLSTM_AR/std/seed=0/log/3.png)
# ![exact](./exact_fig/3.png)

# %%
# !cd datasets/std && python create.py
# Out:
# [160]

# %%
# !bash run.sbatch
# Out:
# + model_name=AE_skipLSTM_AR
# + seed=0
# + windows=6
# + train_percent=0.1
# + dataset=std
# + e_init=10
# + e_train=5
# + e_reinit=100
# + n_cpd=10
# + unit=20
# + horizon=4
# + highway=6
# + skip_sizes='3 5 7'
# + python3 -W ignore ./code/main.py --dataset_name std --seed 0 --windows 6 --train_percent 0.1 --model_name AE_skipLSTM_AR --unit 20 --horizon 4 --highway 6 --skip_sizes 3 5 7 --e_init 10 --e_train 5 --e_reinit 100 --n_cpd 10
# Namespace(dataset_name='std', e_init=10, e_reinit=100, e_train=5, highway=6, horizon=4, model_name='AE_skipLSTM_AR', n_cpd=10, seed=0, skip_sizes=[3, 5, 7], train_percent=0.1, unit=20, windows=6)
# ...

# %%
# !python exact.py
# Out:
# -5 0.1575710432602747 -1 0.8685223758304617
# -5.053662
# Figure(640x480)
# 160

# %% [markdown]
# ![alacpd](./results_AE_skipLSTM_AR/std/seed=0/log/4.png)
# ![exact](./exact_fig/4.png)

# %%
# !cd datasets/std && python create.py
# Out:
# [142]

# %%
# !bash run.sbatch
# Out:
# + model_name=AE_skipLSTM_AR
# + seed=0
# + windows=6
# + train_percent=0.1
# + dataset=std
# + e_init=10
# + e_train=5
# + e_reinit=100
# + n_cpd=10
# + unit=20
# + horizon=4
# + highway=6
# + skip_sizes='3 5 7'
# + python3 -W ignore ./code/main.py --dataset_name std --seed 0 --windows 6 --train_percent 0.1 --model_name AE_skipLSTM_AR --unit 20 --horizon 4 --highway 6 --skip_sizes 3 5 7 --e_init 10 --e_train 5 --e_reinit 100 --n_cpd 10
# Namespace(dataset_name='std', e_init=10, e_reinit=100, e_train=5, highway=6, horizon=4, model_name='AE_skipLSTM_AR', n_cpd=10, seed=0, skip_sizes=[3, 5, 7], train_percent=0.1, unit=20, windows=6)
# ...

# %%
# !python exact.py
# Out:
# -12 0.6026400568526976 -10 0.6833632073273981
# -12.747449
# Figure(640x480)
# 142

# %% [markdown]
# ![alacpd](./results_AE_skipLSTM_AR/std/seed=0/log/5.png)
# ![exact](./exact_fig/5.png)
